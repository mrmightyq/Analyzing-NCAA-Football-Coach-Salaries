# %% [markdown]
# # Intoduction

# %% [markdown]
# After much searching, it was determined that the salary information appears to be for the 2018 season. 2017 variables will be included to see if it predicts coach salary.

# %% [markdown]
# # Data

# %% [markdown]
# https://www.collegegridirons.com/comparisons-by-capacity/
# Stadium Size Data
#
# https://www.sports-reference.com/cfb/years/2017-team-offense.html
# Detailed offense information
#
# https://www.sports-reference.com/cfb/leaders/wins-post-coach-career.html Bowl wins
#
# https://www.sports-reference.com/cfb/leaders/wins-coach-career.html Coach wins
#
# https://sports.usatoday.com/ncaa/finances School finances
#
# https://www.sports-reference.com/cfb/years/2018.html Team Advanced Ratings
#
# https://www.coacheshotseat.com/WinningestActiveCoachesIA.htm Coaches data records
#
# https://web3.ncaa.org/aprsearch/gsrsearch Graduation data
#
# https://github.com/2SUBDA/IST_718 Original data file

# %% [markdown]
# # Reading Cleaning & Combining

# %%
# !pip install fuzzywuzzy
from fuzzywuzzy import fuzz, process
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (0.18.0)

# %%
import pandas as pd #dataframe operations
import numpy as np #arrays and math functions
from scipy.stats import uniform #for training and test splitting
import statsmodels.api as sm #statistical models including regression
import statsmodels.formula.api as sfm #R-like model specification
import matplotlib.pyplot as plt #2D plotting
import seaborn as sns #Provides Trellis and small multiple plotting
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
#Bring in our data set
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57f6e933-eaa2-4ce2-8e45-0e1e039d9633" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57f6e933-eaa2-4ce2-8e45-0e1e039d9633">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Coaches9.csv to Coaches9.csv

# %% [markdown]
# # Base Coaches Dataframe

# %%
import io
coaches = pd.read_csv(io.BytesIO(uploaded['Coaches9.csv']))
print(pd.DataFrame.head(coaches))
# Out:
#                   School Conference  ... AssistantPay        Buyout
# 0              Air Force   Mt. West  ...          $0             --
# 1                  Akron        MAC  ...          $0      $688,500
# 2                Alabama        SEC  ...          $0   $33,600,000
# 3  Alabama at Birmingham      C-USA  ...          $0    $3,847,500
# 4      Appalachian State   Sun Belt  ...          $0    $2,160,417
#
# [5 rows x 9 columns]

# %%
coaches.describe()
# Out:
#          School Conference               Coach  ... BonusPaid AssistantPay Buyout
# count       129        129                 129  ...       129          129    129
# unique      129         11                 129  ...        51            1    102
# top     Liberty      C-USA  Scottie Montgomery  ...        --          $0      --
# freq          1         14                   1  ...        41          129     22
#
# [4 rows x 9 columns]

# %%
coaches.isnull().sum()
# Out:
# School          0
# Conference      0
# Coach           0
# SchoolPay       0
# TotalPay        0
# Bonus           0
# BonusPaid       0
# AssistantPay    0
# Buyout          0
# dtype: int64

# %%
# Define numeric columns 
numColumns = ['SchoolPay', 'TotalPay', 'Bonus', 'BonusPaid', 'AssistantPay', 'Buyout']

# $$$$ Replace dirty data $$$$ 
for i in numColumns:
    coaches[i] = coaches[i].replace('[$,]', '', regex=True)
    coaches[i] = coaches[i].replace('[--]', '0', regex=True)
    coaches[i] = coaches[i].astype(float)
     
coaches.head()
# Out:
#                   School Conference  ... AssistantPay      Buyout
# 0              Air Force   Mt. West  ...          0.0         0.0
# 1                  Akron        MAC  ...          0.0    688500.0
# 2                Alabama        SEC  ...          0.0  33600000.0
# 3  Alabama at Birmingham      C-USA  ...          0.0   3847500.0
# 4      Appalachian State   Sun Belt  ...          0.0   2160417.0
#
# [5 rows x 9 columns]

# %%
# We dont care about assistant pay as it is a meaningless 0 variation coulmn 
del coaches['AssistantPay']
coaches.describe()
# Out:
#           SchoolPay      TotalPay         Bonus     BonusPaid        Buyout
# count  1.290000e+02  1.290000e+02  1.290000e+02  1.290000e+02  1.290000e+02
# mean   2.335563e+06  2.342113e+06  7.250935e+05  1.020011e+05  6.734453e+06
# std    1.898654e+06  1.903114e+06  6.652423e+05  2.088806e+05  1.000138e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.625700e+05  7.625700e+05  2.200000e+05  0.000000e+00  5.223000e+05
# 50%    1.800000e+06  1.830000e+06  6.250000e+05  2.000000e+04  2.671875e+06
# 75%    3.550000e+06  3.550000e+06  1.025000e+06  1.000000e+05  9.000000e+06
# max    8.307000e+06  8.307000e+06  3.100000e+06  1.350000e+06  6.812500e+07

# %%
# Here we decide to just focus on School Pay
# To avoid temptation, all other numeric variables are removed 
coaches = coaches[["TotalPay","Conference","Coach","School"]]
coaches.head()
# Out:
#     TotalPay Conference              Coach                 School
# 0   885000.0   Mt. West       Troy Calhoun              Air Force
# 1   412500.0        MAC       Terry Bowden                  Akron
# 2  8307000.0        SEC         Nick Saban                Alabama
# 3   900000.0      C-USA         Bill Clark  Alabama at Birmingham
# 4   712500.0   Sun Belt  Scott Satterfield      Appalachian State

# %% [markdown]
# # Coach Bowl Wins

# %%
uploaded2 = files.upload()
coaches_bowl = pd.read_csv(io.BytesIO(uploaded2['bowl wins.csv']))
print(pd.DataFrame.head(coaches_bowl))
# Out:
#      <input type="file" id="files-6e8c369b-1439-441a-8300-1e58035b40f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e8c369b-1439-441a-8300-1e58035b40f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bowl wins.csv to bowl wins.csv
#           Coach   W                           University
# 0   Joe Paterno  24                           Penn State
# 1  Bobby Bowden  22          Florida State West Virginia
# 2    Nick Saban  17    Alabama LSU Michigan State Toledo
# 3   Bear Bryant  15  Alabama Kentucky Maryland Texas A&M
# 4    Mack Brown  14          North Carolina Texas Tulane

# %%
# Build the fuzzy matcher
coaches_bowl['CoachFuzz'] = coaches_bowl.Coach.apply(lambda x: [process.extract(x, coaches.Coach, limit=1)][0][0][0])
coaches['CoachFuzz'] = coaches.Coach.apply(lambda x: [process.extract(x, coaches_bowl.Coach, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['Coach', 'Coach']
right_on = ['Coach', 'Coach']

# Merge the two data frames.
df_coach_bowl = pd.merge(coaches, coaches_bowl, how='left', left_on=left_on, right_on=right_on)
#df_coach_record[df_coach_record.W.isnull()]

# %%
df_coach_bowl['Bowl W'] = df_coach_bowl['W'].fillna(0)

# %%
df_coach_bowl=df_coach_bowl[["TotalPay","Conference","School","Coach","Bowl W"]]
df_coach_bowl.head()
# Out:
#     TotalPay Conference                 School              Coach  Bowl W
# 0   885000.0   Mt. West              Air Force       Troy Calhoun     5.0
# 1   412500.0        MAC                  Akron       Terry Bowden     3.0
# 2  8307000.0        SEC                Alabama         Nick Saban    17.0
# 3   900000.0      C-USA  Alabama at Birmingham         Bill Clark     0.0
# 4   712500.0   Sun Belt      Appalachian State  Scott Satterfield     4.0

# %% [markdown]
# # Coach Career Records

# %%
uploaded3 = files.upload()
# Out:
#      <input type="file" id="files-8e7f0bb5-f486-452c-8266-13cec5784639" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e7f0bb5-f486-452c-8266-13cec5784639">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving coach wins career.csv to coach wins career.csv

# %%
coaches_career = pd.read_csv(io.BytesIO(uploaded3['coach wins career.csv']))
print(pd.DataFrame.head(coaches_career))
# Out:
#   Rank            Coach        School  ...  School W School L School Win %
# 0    1         Ryan Day    Ohio State  ...        21        1        0.955
# 1    2     Kalen DeBoer  Fresno State  ...         3        2        0.600
# 2    3    Lincoln Riley      Oklahoma  ...        43        8        0.843
# 3    4     Dabo Swinney       Clemson  ...       139       32        0.813
# 4    5  Eliah Drinkwitz      Missouri  ...         5        3        0.625
#
# [5 rows x 14 columns]

# %%
# Build the fuzzy matcher
coaches_career['CoachFuzz'] = coaches_career.Coach.apply(lambda x: [process.extract(x, df_coach_bowl.Coach, limit=1)][0][0][0])
df_coach_bowl['CoachFuzz'] = df_coach_bowl.Coach.apply(lambda x: [process.extract(x, coaches_career.Coach, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['Coach', 'Coach']
right_on = ['Coach', 'Coach']

# Merge the two data frames.
df_2 = pd.merge(df_coach_bowl, coaches_career, how='left', left_on=left_on, right_on=right_on)
df_2.head()
#df_coach_record[df_coach_record.W.isnull()]
# Out:
#     TotalPay Conference  ... School Win %        CoachFuzz_y
# 0   885000.0   Mt. West  ...     0.587000       Troy Calhoun
# 1   412500.0        MAC  ...     0.402299       Terry Bowden
# 2  8307000.0        SEC  ...     0.878000         Nick Saban
# 3   900000.0      C-USA  ...     0.633000         Bill Clark
# 4   712500.0   Sun Belt  ...     0.455000  Scott Satterfield
#
# [5 rows x 20 columns]

# %%
df_coach_final=df_2[["TotalPay","Conference","Coach","Bowl W","School_x","Age","Career Yrs.","Career W","Career L", "Career Win %", "School Yrs.", "School W", "School L", "School Win %"]]
df_coach_final = df_coach_final.rename(columns={'School_x': 'School'})
df_coach_final.head()
# Out:
#     TotalPay Conference              Coach  ...  School W School L  School Win %
# 0   885000.0   Mt. West       Troy Calhoun  ...       101       71      0.587000
# 1   412500.0        MAC       Terry Bowden  ...        35       52      0.402299
# 2  8307000.0        SEC         Nick Saban  ...       166       23      0.878000
# 3   900000.0      C-USA         Bill Clark  ...        38       22      0.633000
# 4   712500.0   Sun Belt  Scott Satterfield  ...        10       12      0.455000
#
# [5 rows x 14 columns]

# %%
df_coach_final.isnull().sum()
# Out:
# TotalPay        0
# Conference      0
# Coach           0
# Bowl W          0
# School          0
# Age             0
# Career Yrs.     0
# Career W        0
# Career L        0
# Career Win %    0
# School Yrs.     0
# School W        0
# School L        0
# School Win %    0
# dtype: int64

# %% [markdown]
# # Program Revenue

# %%
uploaded4 = files.upload()
# Out:
#      <input type="file" id="files-4d3af913-b921-41f0-b337-1a74bb7f4dc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d3af913-b921-41f0-b337-1a74bb7f4dc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving program revenue.csv to program revenue.csv

# %%
program_revenue = pd.read_csv(io.BytesIO(uploaded4['program revenue.csv']))
print(pd.DataFrame.head(program_revenue))
# Out:
#     RK      SCHOOL     CONF  ... TOTAL EXPENSES TOTAL ALLOCATED % ALLOCATED
# 0  1.0       Texas   Big 12  ...  $204,234,897              $0         0.00
# 1  2.0   Texas A&M      SEC  ...  $169,012,456              $0         0.00
# 2  3.0  Ohio State  Big Ten  ...  $220,572,956              $0         0.00
# 3  4.0    Michigan  Big Ten  ...  $190,952,175        $261,773         0.13
# 4  5.0     Georgia      SEC  ...  $143,299,554      $3,508,850         2.02
#
# [5 rows x 7 columns]

# %%
# Build the fuzzy matcher
program_revenue['SchoolFuzz'] = program_revenue.SCHOOL.apply(lambda x: [process.extract(x, df_coach_final.School, limit=1)][0][0][0])
df_coach_final['SchoolFuzz'] = df_coach_final.School.apply(lambda x: [process.extract(x, program_revenue.SCHOOL, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['School', 'SchoolFuzz']
right_on = ['SCHOOL', 'SchoolFuzz']

# Merge the two data frames.
df_coach_revenue = pd.merge(df_coach_final, program_revenue, how='left', left_on=left_on, right_on=right_on)

# %%
# Remove commas from Capacity variable and convert to numeric
df_coach_revenue['Program Revenue'] = df_coach_revenue['TOTAL REVENUE'].replace(',', '', regex=True).astype(float)

df_coach_revenue.drop(columns=['RK', 'SCHOOL','CONF',"TOTAL EXPENSES","TOTAL ALLOCATED","% ALLOCATED","SchoolFuzz","TOTAL REVENUE"],inplace=True,axis=1)
df_coach_revenue.head()
# Out:
#     TotalPay Conference  ... School Win %  Program Revenue
# 0   885000.0   Mt. West  ...     0.587000       60009782.0
# 1   412500.0        MAC  ...     0.402299       37194485.0
# 2  8307000.0        SEC  ...     0.878000      164090889.0
# 3   900000.0      C-USA  ...     0.633000       36494381.0
# 4   712500.0   Sun Belt  ...     0.455000       37996512.0
#
# [5 rows x 15 columns]

# %% [markdown]
# # Stadium Seating

# %%
uploaded5 = files.upload()
# Out:
#      <input type="file" id="files-d759ce1b-f44a-4030-9d20-deaa5611859b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d759ce1b-f44a-4030-9d20-deaa5611859b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stadiums.csv to stadiums.csv

# %%
stadiums = pd.read_csv(io.BytesIO(uploaded5['stadiums.csv']))
print(pd.DataFrame.head(stadiums))
# Out:
#             Stadium     College Conference Capacity  Opened
# 0  Michigan Stadium    Michigan    Big Ten  107,601  1927.0
# 1    Beaver Stadium  Penn State    Big Ten  106,572  1960.0
# 2      Ohio Stadium  Ohio State    Big Ten  104,944  1922.0
# 3        Kyle Field   Texas A&M        SEC  102,733  1904.0
# 4   Neyland Stadium   Tennessee        SEC  102,521  1921.0

# %%
# Remove commas from Capacity variable and convert to numeric
stadiums['Capacity'] = stadiums['Capacity'].replace(',', '', regex=True).astype(float)
stadiums.head()
# Out:
#             Stadium     College Conference  Capacity  Opened
# 0  Michigan Stadium    Michigan    Big Ten  107601.0  1927.0
# 1    Beaver Stadium  Penn State    Big Ten  106572.0  1960.0
# 2      Ohio Stadium  Ohio State    Big Ten  104944.0  1922.0
# 3        Kyle Field   Texas A&M        SEC  102733.0  1904.0
# 4   Neyland Stadium   Tennessee        SEC  102521.0  1921.0

# %%
# Build the fuzzy matcher
stadiums['SchoolFuzz'] = stadiums.College.apply(lambda x: [process.extract(x, df_coach_revenue.School, limit=1)][0][0][0])
df_coach_revenue['SchoolFuzz'] = df_coach_revenue.School.apply(lambda x: [process.extract(x, stadiums.College, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['School', 'SchoolFuzz']
right_on = ['College', 'SchoolFuzz']

# Merge the two data frames.
df_3 = pd.merge(df_coach_final, stadiums, how='left', left_on=left_on, right_on=right_on)

# %%
df_3.drop(columns=['SchoolFuzz', 'Stadium','College',"Conference_y","Opened"],inplace=True,axis=1)
df_3.head()
# Out:
#     TotalPay Conference_x              Coach  ...  School L School Win %  Capacity
# 0   885000.0     Mt. West       Troy Calhoun  ...        71     0.587000   52237.0
# 1   412500.0          MAC       Terry Bowden  ...        52     0.402299   30000.0
# 2  8307000.0          SEC         Nick Saban  ...        23     0.878000  101821.0
# 3   900000.0        C-USA         Bill Clark  ...        22     0.633000   71594.0
# 4   712500.0     Sun Belt  Scott Satterfield  ...        12     0.455000   24150.0
#
# [5 rows x 15 columns]

# %%
print(df_3.isnull().sum())
print(len(df_3))
# Out:
# TotalPay        0
# Conference_x    0
# Coach           0
# Bowl W          0
# School          0
# Age             0
# Career Yrs.     0
# Career W        0
# Career L        0
# Career Win %    0
# School Yrs.     0
# School W        0
# School L        0
# School Win %    0
# Capacity        0
# dtype: int64
# 129

# %%
# Build the fuzzy matcher
df_coach_revenue["School2"]=df_coach_revenue["School"]
df_coach_revenue.drop(columns=['TotalPay', 'Conference','Bowl W',"Age","Career Yrs.","Career W","Career Win %","School","Coach","Career L","School Yrs.","School W","School L","School Win %"],inplace=True,axis=1)
df_coach_revenue['SchoolFuzz'] = df_coach_revenue.School2.apply(lambda x: [process.extract(x, df_3.School, limit=1)][0][0][0])
df_3['SchoolFuzz'] = df_3.School.apply(lambda x: [process.extract(x, df_coach_revenue.School2, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['School', 'SchoolFuzz']
right_on = ['School2', 'SchoolFuzz']

# Merge the two data frames.
df_aa = pd.merge(df_3, df_coach_revenue, how='left', left_on=left_on, right_on=right_on)
df_aa.drop(columns=['SchoolFuzz', 'School2'],inplace=True,axis=1)

# %%
df_3= df_aa
df_3.head()
# Out:
#     TotalPay Conference_x  ...  Capacity  Program Revenue
# 0   885000.0     Mt. West  ...   52237.0       60009782.0
# 1   412500.0          MAC  ...   30000.0       37194485.0
# 2  8307000.0          SEC  ...  101821.0      164090889.0
# 3   900000.0        C-USA  ...   71594.0       36494381.0
# 4   712500.0     Sun Belt  ...   24150.0       37996512.0
#
# [5 rows x 16 columns]

# %% [markdown]
# # Team AP Ratings

# %%
uploaded6 = files.upload()
# Out:
#      <input type="file" id="files-c935b91c-9b1f-4f1a-bc08-f3cd1b753939" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c935b91c-9b1f-4f1a-bc08-f3cd1b753939">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving team ratings.csv to team ratings.csv

# %%
team = pd.read_csv(io.BytesIO(uploaded6['team ratings.csv']))
print(pd.DataFrame.head(team))
# Out:
#    Rk                School            Conf  ...  AP Pre  AP High  AP Rank
# 0   1               Clemson  ACC (Atlantic)  ...     5.0      1.0      4.0
# 1   2  North Carolina State  ACC (Atlantic)  ...     NaN     14.0     23.0
# 2   3            Louisville  ACC (Atlantic)  ...    16.0     14.0      NaN
# 3   4           Wake Forest  ACC (Atlantic)  ...     NaN      NaN      NaN
# 4   5        Boston College  ACC (Atlantic)  ...     NaN      NaN      NaN
#
# [5 rows x 16 columns]

# %%
# Build the fuzzy matcher
team['SchoolFuzz'] = team.School.apply(lambda x: [process.extract(x, df_3.School, limit=1)][0][0][0])
df_3['SchoolFuzz'] = df_3.School.apply(lambda x: [process.extract(x, team.School, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['School', 'SchoolFuzz']
right_on = ['School', 'SchoolFuzz']

# Merge the two data frames.
df_4 = pd.merge(df_3, team, how='left', left_on=left_on, right_on=right_on)

# %%
df_4.drop(columns=['SchoolFuzz', 'Conf','Rk'],inplace=True,axis=1)
df_4.head()
# Out:
#     TotalPay Conference_x              Coach  ...  AP Pre AP High  AP Rank
# 0   885000.0     Mt. West       Troy Calhoun  ...     NaN     NaN      NaN
# 1   412500.0          MAC       Terry Bowden  ...     NaN     NaN      NaN
# 2  8307000.0          SEC         Nick Saban  ...     1.0     1.0      1.0
# 3   900000.0        C-USA         Bill Clark  ...     NaN     NaN      NaN
# 4   712500.0     Sun Belt  Scott Satterfield  ...     NaN     NaN      NaN
#
# [5 rows x 29 columns]

# %%
df_4['AP Pre'] = df_4['AP Pre'].fillna(50)
df_4['AP High'] = df_4['AP High'].fillna(50)
df_4['AP Rank'] = df_4['AP Rank'].fillna(50)
df_4.head()
# Out:
#     TotalPay Conference_x              Coach  ...  AP Pre AP High  AP Rank
# 0   885000.0     Mt. West       Troy Calhoun  ...    50.0    50.0     50.0
# 1   412500.0          MAC       Terry Bowden  ...    50.0    50.0     50.0
# 2  8307000.0          SEC         Nick Saban  ...     1.0     1.0      1.0
# 3   900000.0        C-USA         Bill Clark  ...    50.0    50.0     50.0
# 4   712500.0     Sun Belt  Scott Satterfield  ...    50.0    50.0     50.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Team Detailed Stats

# %%
uploaded7 = files.upload()
# Out:
#      <input type="file" id="files-770746a2-a333-4969-b107-2fe6ae6dce7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-770746a2-a333-4969-b107-2fe6ae6dce7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving team detailed stats.csv to team detailed stats.csv

# %%
team2 = pd.read_csv(io.BytesIO(uploaded7['team detailed stats.csv']))
print(pd.DataFrame.head(team2))
# Out:
#    Rk          School   G  ...  TurnoversFum  TurnoversInt  TurnoversTot
# 0   1             UCF  13  ...           0.5           0.7           1.2
# 1   2         Memphis  13  ...           0.5           0.8           1.2
# 2   3        Oklahoma  14  ...           0.5           0.4           0.9
# 3   4  Oklahoma State  13  ...           0.8           0.8           1.6
# 4   5         Arizona  13  ...           0.7           1.0           1.7
#
# [5 rows x 25 columns]

# %%
# Build the fuzzy matcher
team2['SchoolFuzz'] = team2.School.apply(lambda x: [process.extract(x, df_4.School, limit=1)][0][0][0])
df_4['SchoolFuzz'] = df_4.School.apply(lambda x: [process.extract(x, team2.School, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['School', 'SchoolFuzz']
right_on = ['School', 'SchoolFuzz']

# Merge the two data frames.
df_5 = pd.merge(df_4, team2, how='left', left_on=left_on, right_on=right_on)

# %%
df_5.drop(columns=['SchoolFuzz', 'G','Rk'],inplace=True,axis=1)
df_5 = df_5.rename(columns={'Conference_x': 'Conference'})
print(len(df_5))
df_5.head()
# Out:
# 129
#     TotalPay Conference  ... TurnoversInt  TurnoversTot
# 0   885000.0   Mt. West  ...          0.5           1.7
# 1   412500.0        MAC  ...          0.8           1.2
# 2  8307000.0        SEC  ...          0.2           0.7
# 3   900000.0      C-USA  ...          NaN           NaN
# 4   712500.0   Sun Belt  ...          0.5           1.1
#
# [5 rows x 51 columns]

# %% [markdown]
# # Graduation Rates

# %%
uploaded8 = files.upload()
# Out:
#      <input type="file" id="files-1cab0855-1f59-4f79-9da0-703b9d928f15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1cab0855-1f59-4f79-9da0-703b9d928f15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving graduation.csv to graduation.csv

# %%
grad = pd.read_csv(io.BytesIO(uploaded8['graduation.csv']))
print(pd.DataFrame.head(grad))
# Out:
#    Cohort Year                        School  ...   GSR   FGR
# 0         2013  Abilene Christian University  ...  74.0  53.0
# 1         2013           University of Akron  ...  78.0  67.0
# 2         2013        Alabama A&M University  ...  58.0  48.0
# 3         2013      Alabama State University  ...  67.0  41.0
# 4         2013         University of Alabama  ...  88.0  63.0
#
# [5 rows x 7 columns]

# %%
# Cleaning Graduation Rate data set. 

# Rename Conferences.
grOrgName = ['Southland Conference', 'Mid-American Conference', 'Southwestern Athletic Conf.', 'Southeastern Conference', 'Conference USA',
             'Colonial Athletic Association', 'Sun Belt Conference', 'Pac-12 Conference', 'Ohio Valley Conference', 'Big South Conference',
             'Big 12 Conference', 'Mid-Eastern Athletic Conf.', 'Mountain West Conference', 'Atlantic Coast Conference', 'Independent', 
             'The Ivy League', 'Northeast Conference', 'Patriot League', 'Pioneer Football League', 'Big Sky Conference', 
             'American Athletic Conference', 'Southern Conference', 'Missouri Valley Football Conference', 'Big Ten Conference']

grNewName = ['SLC', 'MAC', 'SWAC', 'SEC', 'C-USA', 'CAA', 'Sun Belt', 'Pac-12', 'OVC', 'Big South', 'Big 12', 'MEAC', 'Mt. West', 'ACC', 'Ind.', 
            'Ivy', 'NEC', 'Patriot League', 'PFL', 'Big Sky', 'AAC', 'SoCon', 'MVFC', 'Big Ten']

grad['Conference'] = grad['Conference'].replace(grOrgName, grNewName, regex=False)

# Check final result to see that everything is correct. 
grad.head()
# Out:
#    Cohort Year                        School Conference  ... State   GSR   FGR
# 0         2013  Abilene Christian University        SLC  ...    TX  74.0  53.0
# 1         2013           University of Akron        MAC  ...    OH  78.0  67.0
# 2         2013        Alabama A&M University       SWAC  ...    AL  58.0  48.0
# 3         2013      Alabama State University       SWAC  ...    AL  67.0  41.0
# 4         2013         University of Alabama        SEC  ...    AL  88.0  63.0
#
# [5 rows x 7 columns]

# %%
# Additional cleaning needed to be done in order to get a full match with fuzzywuzzy. 
# Original names in df_coach_record data set.
oldSchool = ['Connecticut', 'Georgia Tech', 'Miami (Fla.)', 'Virginia', 'Virginia Tech', 'Kansas', 'Kansas State', 'Texas', 
            'Illinois', 'Indiana', 'Iowa', 'Michigan', 'Northwestern', 'Penn State', 'Rutgers', 'Texas-San Antonio', 
            'Fresno State', 'New Mexico', 'California', 'Colorado', 'UCLA', 'Utah', 'Washington', 'Alabama', 'Arkansas', 'Florida', 
            'Georgia', 'Kentucky', 'LSU', 'South Carolina', 'Tennessee', 'Louisiana-Monroe']

# School names as they appear on graduation_rate data set. 
newSchool = ['University of Connecticut', 'Georgia Institute of Technology', 'University of Miami (Florida)', 'University of Virginia', 
            'Virginia Polytechnic Institute and State University', 'University of Kansas', 'Kansas State University', 
            'University of Texas at Austin', 'University of Illinois Urbana-Champaign', 'Indiana University, Bloomington', 
            'University of Iowa', 'University of Michigan', 'Northwestern University', 'Pennsylvania State University', 
            'Rutgers, The State University of New Jersey, New Brunswick', 'University of Texas at San Antonio', 
            'California State University, Fresno', 'University of New Mexico', 'University of California, Berkeley', 
            'University of Colorado, Boulder', 'University of California, Los Angeles', 'University of Utah', 'University of Washington', 
            'University of Alabama', 'University of Arkansas, Fayetteville', 'University of Florida', 'University of Georgia', 
            'University of Kentucky', 'Louisiana State University', 'University of South Carolina, Columbia', 
            'University of Tennessee, Knoxville', 'University of Louisiana at Monroe']

# Replaces old names with new names so data sets match one-on-one
df_5['School'] = df_5['School'].replace(oldSchool, newSchool, regex=False)

# %%
# Build the fuzzy matcher
df_5['SchoolFuzz'] = df_5.School.apply(lambda x: [process.extract(x, grad.School, limit=1)][0][0][0])

# Select columns from coaches and records that should be linked. 
left_on = ['Conference', 'SchoolFuzz']
right_on = ['Conference', 'School']

# Merge the two data frames.
df_6 = pd.merge(df_5, grad, how='left', left_on=left_on, right_on=right_on)
df_6.head()
# Out:
#     TotalPay Conference              Coach  Bowl W  ...     Sport  State   GSR   FGR
# 0   885000.0   Mt. West       Troy Calhoun     5.0  ...  Football     CO  87.0   NaN
# 1   412500.0        MAC       Terry Bowden     3.0  ...  Football     OH  78.0  67.0
# 2  8307000.0        SEC         Nick Saban    17.0  ...  Football     AL  88.0  63.0
# 3   900000.0      C-USA         Bill Clark     0.0  ...  Football     AL  73.0  47.0
# 4   712500.0   Sun Belt  Scott Satterfield     4.0  ...  Football     NC  77.0  65.0
#
# [5 rows x 58 columns]

# %%
df_6.drop(columns=['SchoolFuzz', 'Cohort Year','Sport','School_y'],inplace=True,axis=1)
print(len(df_6))
# Out:
# 129

# %%
df_6.rename(columns={'School_x': 'School'},inplace=True)
df_6.head()
# Out:
#     TotalPay Conference              Coach  ...  State   GSR   FGR
# 0   885000.0   Mt. West       Troy Calhoun  ...     CO  87.0   NaN
# 1   412500.0        MAC       Terry Bowden  ...     OH  78.0  67.0
# 2  8307000.0        SEC         Nick Saban  ...     AL  88.0  63.0
# 3   900000.0      C-USA         Bill Clark  ...     AL  73.0  47.0
# 4   712500.0   Sun Belt  Scott Satterfield  ...     NC  77.0  65.0
#
# [5 rows x 54 columns]

# %%
df_6['GSR'].fillna((df_6['GSR'].mean()), inplace=True)
df_6['FGR'].fillna((df_6['FGR'].mean()), inplace=True)

# %%
df_6[df_6.isnull().any(axis=1)]
# Out:
#       TotalPay Conference             Coach  ...  State        GSR     FGR
# 3     900000.0      C-USA        Bill Clark  ...     AL  73.000000  47.000
# 9     932521.0       Ind.       Jeff Monken  ...    NaN  80.181102  62.904
# 15    437228.0        MAC        Mike Jinks  ...     OH  78.000000  68.000
# 16         0.0       Ind.     Kalani Sitake  ...     UT  70.000000  40.000
# 19   1700000.0        AAC       Josh Heupel  ...     FL  81.000000  65.000
# 41   1750000.0        AAC  Major Applewhite  ...    NaN  80.181102  62.904
# 50    947281.0       Ind.       Turner Gill  ...     VA  65.000000  55.000
# 52    850000.0   Sun Belt      Billy Napier  ...     LA  85.000000  68.000
# 58    500000.0       Ind.      Mark Whipple  ...     MA  67.000000  51.000
# 60   4058061.0        ACC        Mark Richt  ...     FL  76.000000  42.000
# 61    524826.0        MAC      Chuck Martin  ...     OH  89.000000  72.000
# 64    803004.0      C-USA   Rick Stockstill  ...     TN  95.000000  70.000
# 66   3000000.0        SEC         Matt Luke  ...     MS  81.000000  68.000
# 72    600000.0   Mt. West      Tony Sanchez  ...     NV  69.000000  61.000
# 80   2129638.0       Ind.       Brian Kelly  ...     IN  91.000000  85.000
# 89   3017718.0        ACC      Pat Narduzzi  ...     PA  86.000000  56.000
# 98   2625965.0     Pac-12       Clay Helton  ...     CA  82.000000  62.000
# 99         0.0        AAC       Sonny Dykes  ...     TX  75.000000  64.000
# 109   700000.0      C-USA        Dana Dimel  ...     TX  81.000000  62.000
# 110  1100000.0      C-USA      Frank Wilson  ...     TX  83.000000  61.000
#
# [20 rows x 54 columns]

# %%
df_6.at[9, 'State'] = "NY"
df_6.at[41, 'State'] = "TX"

# %%
df_6.isnull().sum()
# Out:
# TotalPay               0
# Conference             0
# Coach                  0
# Bowl W                 0
# School                 0
# Age                    0
# Career Yrs.            0
# Career W               0
# Career L               0
# Career Win %           0
# School Yrs.            0
# School W               0
# School L               0
# School Win %           0
# Capacity               0
# Program Revenue        0
# Overall W             15
# Overall L             15
# Overall Pct           15
# Conference W          17
# Conference L          17
# Conference Pct        18
# PPG Off               15
# PPG Def               15
# SRS                   15
# SOS                   15
# AP Pre                 0
# AP High                0
# AP Rank                0
# Pts                   15
# Passing Cmp           15
# PassingAtt            15
# PassingPct            15
# PassingYds            15
# PassingTD             15
# RushingAtt            15
# RushingYds            15
# RushingAvg            15
# RushingTD             15
# Total OffensePlays    15
# Total OffenseYds      15
# Total OffenseAvg      15
# First DownsPass       15
# First DownsRush       15
# First DownsPen        15
# First DownsTot        15
# PenaltiesNo.          15
# PenaltiesYds          15
# TurnoversFum          15
# TurnoversInt          15
# TurnoversTot          15
# State                  0
# GSR                    0
# FGR                    0
# dtype: int64

# %% [markdown]
# # US MAP Plots

# %%
import requests
from bs4 import BeautifulSoup
import plotly.express as px

# %%
map_df = df_6[["TotalPay", "State"]]
map_df.head()
# Out:
#     TotalPay State
# 0   885000.0    CO
# 1   412500.0    OH
# 2  8307000.0    AL
# 3   900000.0    AL
# 4   712500.0    NC

# %%
map_2=map_df.groupby("State").mean().reset_index()
#map_2 = pd.DataFrame(map_2, columns=['State', 'TotalPay'])
map_2.head()
# Out:
#   State      TotalPay
# 0    AL  3.464531e+06
# 1    AR  2.162500e+06
# 2    AZ  2.000000e+06
# 3    CA  2.107358e+06
# 4    CO  1.854500e+06

# %%
fig = px.choropleth(map_2,
                    locations='State',
                    color='TotalPay',
                    color_continuous_scale='spectral_r',
                    hover_name='State',
                    locationmode='USA-states',
                    labels={'TotalPay':'Coach Total Pay'},
                    title="Average Coach Pay by State",
                    scope='usa')
fig.update_layout(
    #title="Average Coach Pay by State",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="RebeccaPurple"
    )
)
fig.update_layout(
    title={
        'text': "Average Coach Pay by State",
        'y':0.9,
        'x':0.45,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc60cd77-b267-49a3-9226-ffa1f2949ea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc60cd77-b267-49a3-9226-ffa1f2949ea8")) {
#                     Plotly.newPlot(
#                         'dc60cd77-b267-49a3-9226-ffa1f2949ea8',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>State=%{location}<br>Coach Total Pay=%{z}", "hovertext": ["AL", "AR", "AZ", "CA", "CO", "CT", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "MI", "MN", "MO", "MS", "NC", "NE", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "SC", "TN", "TX", "UT", "VA", "WA", "WI", "WV", "WY"], "locationmode": "USA-states", "locations": ["AL", "AR", "AZ", "CA", "CO", "CT", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "MI", "MN", "MO", "MS", "NC", "NE", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "SC", "TN", "TX", "UT", "VA", "WA", "WI", "WV", "WY"], "name": "", "type": "choropleth", "z": [3464531.2, 2162500.0, 2000000.0, 2107358.285714286, 1854500.0, 1100000.0, 2824723.0, 2720654.5, 486504.0, 4100000.0, 1650010.0, 3084411.6666666665, 2048831.75, 2600554.5, 2933294.6666666665, 1413800.0, 1507429.5, 2337500.0, 2761883.4, 3550000.0, 2350000.0, 2033333.3333333333, 1769644.0, 5000000.0, 2200000.0, 621690.0, 550000.0, 1263075.6666666667, 1639985.625, 3772725.6666666665, 2200004.0, 3908859.0, 3714450.0, 2515381.75, 2268307.6666666665, 1562639.0, 2287987.0, 3938750.0, 3750000.0, 2190035.0, 1412000.0]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Coach Total Pay"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "font": {"color": "RebeccaPurple", "family": "Courier New, monospace", "size": 18}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": ...

# %%
map_max=map_df.groupby(['State'], sort=False)['TotalPay'].max().reset_index()
fig2 = px.choropleth(map_max,
                    locations='State',
                    color='TotalPay',
                    color_continuous_scale='spectral_r',
                    hover_name='State',
                    locationmode='USA-states',
                    labels={'TotalPay':'Max Coach Pay'},
                    title="Max Coach Pay by State",
                    scope='usa')
fig2.update_layout(
    #title="Average Coach Pay by State",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="RebeccaPurple"
    )
)
fig2.update_layout(
    title={
        'text': "Max Coach Pay by State",
        'y':0.9,
        'x':0.46,
        'xanchor': 'center',
        'yanchor': 'top'})

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0e86bd86-2beb-4604-bebd-7f4200983d4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0e86bd86-2beb-4604-bebd-7f4200983d4e")) {
#                     Plotly.newPlot(
#                         '0e86bd86-2beb-4604-bebd-7f4200983d4e',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>State=%{location}<br>Max Coach Pay=%{z}", "hovertext": ["CO", "OH", "AL", "NC", "AZ", "AR", "NY", "IN", "TX", "ID", "MA", "UT", "CA", "FL", "MI", "SC", "CT", "GA", "HI", "IL", "IA", "KS", "KY", "VA", "LA", "WV", "MD", "TN", "MN", "MS", "MO", "NE", "NV", "NM", "OK", "OR", "PA", "NJ", "WA", "WI", "WY"], "locationmode": "USA-states", "locations": ["CO", "OH", "AL", "NC", "AZ", "AR", "NY", "IN", "TX", "ID", "MA", "UT", "CA", "FL", "MI", "SC", "CT", "GA", "HI", "IL", "IA", "KS", "KY", "VA", "LA", "WV", "MD", "TN", "MN", "MS", "MO", "NE", "NV", "NM", "OK", "OR", "PA", "NJ", "WA", "WI", "WY"], "name": "", "type": "choropleth", "z": [2878500.0, 7600000.0, 8307000.0, 3000000.0, 2000000.0, 3500000.0, 2401206.0, 3800000.0, 7500000.0, 1650010.0, 2514859.0, 3787917.0, 4311543.0, 6070000.0, 7504000.0, 6543350.0, 1100000.0, 6603600.0, 486504.0, 5000000.0, 4700000.0, 3500000.0, 4013600.0, 4000000.0, 3500000.0, 3617500.0, 2512000.0, 3846000.0, 3550000.0, 3000000.0, 2350000.0, 5000000.0, 600000.0, 823740.0, 5000000.0, 2500000.0, 4800000.0, 2200000.0, 4377500.0, 3750000.0, 1412000.0]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Max Coach Pay"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "font": {"color": "RebeccaPurple", "family": "Courier New, monospace", "size": 18}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": " ...

# %% [markdown]
# Feels good to coach in the deep South (SEC probably) and also some Big 10 lovin' in the midwest

# %% [markdown]
# # Develop a geographic visualization that in your view best depicts the conferences’ median salary

# %%
map_3=df_6.groupby(['Conference','State']).median().reset_index()
#map_2 = pd.DataFrame(map_2, columns=['State', 'TotalPay'])
conf_med= map_3[['Conference','State','TotalPay']]
conf_med
# Out:
#    Conference State   TotalPay
# 0         AAC    CT  1100000.0
# 1         AAC    FL  1350000.0
# 2         AAC    LA  1629000.0
# 3         AAC    MD  2163000.0
# 4         AAC    NC  1102500.0
# ..        ...   ...        ...
# 82   Sun Belt    GA   609500.0
# 83   Sun Belt    LA   620000.0
# 84   Sun Belt    NC   712500.0
# 85   Sun Belt    SC   400000.0
# 86   Sun Belt    TX   700000.0
#
# [87 rows x 3 columns]

# %%
ACC =(conf_med.loc[conf_med['Conference'] == 'ACC'])
SEC =(conf_med.loc[conf_med['Conference'] == 'SEC'])
Big10 =(conf_med.loc[conf_med['Conference'] == 'Big Ten'])

# %%
fig3 = px.choropleth(ACC,
                    locations='State',
                    color='TotalPay',
                    color_continuous_scale='spectral_r',
                    hover_name='State',
                    locationmode='USA-states',
                    labels={'TotalPay':'Median Coach Pay'},
                    title="Median ACC Coach Pay by State",
                    scope='usa')
fig3.update_layout(
    title={
        'text': "Median ACC Coach Pay by State",
        'y':0.9,
        'x':0.46,
        'xanchor': 'center',
        'yanchor': 'top'})

fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="757983a4-c67c-4e55-becc-929a76af7567" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("757983a4-c67c-4e55-becc-929a76af7567")) {
#                     Plotly.newPlot(
#                         '757983a4-c67c-4e55-becc-929a76af7567',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>State=%{location}<br>Median Coach Pay=%{z}", "hovertext": ["FL", "GA", "KY", "MA", "NC", "NY", "PA", "SC", "VA"], "locationmode": "USA-states", "locations": ["FL", "GA", "KY", "MA", "NC", "NY", "PA", "SC", "VA"], "name": "", "type": "choropleth", "z": [4529030.5, 3060018.0, 3980434.0, 2514859.0, 2557964.0, 2401206.0, 3017718.0, 6543350.0, 3775000.0]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Median Coach Pay"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tic ...

# %%
fig4 = px.choropleth(SEC,
                    locations='State',
                    color='TotalPay',
                    color_continuous_scale='spectral_r',
                    hover_name='State',
                    locationmode='USA-states',
                    labels={'TotalPay':'Median Coach Pay'},
                    title="Median ACC Coach Pay by State",
                    scope='usa')
fig4.update_layout(
    title={
        'text': "Median SEC Coach Pay by State",
        'y':0.9,
        'x':0.46,
        'xanchor': 'center',
        'yanchor': 'top'})

fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="93874aed-61a8-4d8e-94b3-ee8d248c0f31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93874aed-61a8-4d8e-94b3-ee8d248c0f31")) {
#                     Plotly.newPlot(
#                         '93874aed-61a8-4d8e-94b3-ee8d248c0f31',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>State=%{location}<br>Median Coach Pay=%{z}", "hovertext": ["AL", "AR", "FL", "GA", "KY", "LA", "MO", "MS", "SC", "TN", "TX"], "locationmode": "USA-states", "locations": ["AL", "AR", "FL", "GA", "KY", "LA", "MO", "MS", "SC", "TN", "TX"], "name": "", "type": "choropleth", "z": [7506328.0, 3500000.0, 6070000.0, 6603600.0, 4013600.0, 3500000.0, 2350000.0, 2800000.0, 4200000.0, 3329261.5, 7500000.0]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Median Coach Pay"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tic ...

# %%
fig5 = px.choropleth(Big10,
                    locations='State',
                    color='TotalPay',
                    color_continuous_scale='spectral_r',
                    hover_name='State',
                    locationmode='USA-states',
                    labels={'TotalPay':'Median Coach Pay'},
                    title="Median Big 10 Coach Pay by State",
                    scope='usa')
fig5.update_layout(
    title={
        'text': "Median Big 10 Coach Pay by State",
        'y':0.9,
        'x':0.46,
        'xanchor': 'center',
        'yanchor': 'top'})

fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f8484d59-8920-4d9a-800f-1d90138f582c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f8484d59-8920-4d9a-800f-1d90138f582c")) {
#                     Plotly.newPlot(
#                         'f8484d59-8920-4d9a-800f-1d90138f582c',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>State=%{location}<br>Median Coach Pay=%{z}", "hovertext": ["IA", "IL", "IN", "MD", "MI", "MN", "NE", "NJ", "OH", "PA", "WI"], "locationmode": "USA-states", "locations": ["IA", "IL", "IN", "MD", "MI", "MN", "NE", "NJ", "OH", "PA", "WI"], "name": "", "type": "choropleth", "z": [4700000.0, 4309887.5, 2815000.0, 2512000.0, 5947208.5, 3550000.0, 5000000.0, 2200000.0, 7600000.0, 4800000.0, 3750000.0]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Median Coach Pay"}}, "colorscale": [[0.0, "rgb(94,79,162)"], [0.1, "rgb(50,136,189)"], [0.2, "rgb(102,194,165)"], [0.3, "rgb(171,221,164)"], [0.4, "rgb(230,245,152)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(254,224,139)"], [0.7, "rgb(253,174,97)"], [0.8, "rgb(244,109,67)"], [0.9, "rgb(213,62,79)"], [1.0, "rgb(158,1,66)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tic ...

# %% [markdown]
# # Final Data Cleaning

# %%
#Drop it like it's hot
df_clean=df_6.dropna()
print(len(df_clean))
df_clean.head()
# Out:
# 110
#     TotalPay Conference              Coach  ...  State   GSR     FGR
# 0   885000.0   Mt. West       Troy Calhoun  ...     CO  87.0  62.904
# 1   412500.0        MAC       Terry Bowden  ...     OH  78.0  67.000
# 2  8307000.0        SEC         Nick Saban  ...     AL  88.0  63.000
# 4   712500.0   Sun Belt  Scott Satterfield  ...     NC  77.0  65.000
# 5  2000000.0     Pac-12       Kevin Sumlin  ...     AZ  75.0  57.000
#
# [5 rows x 54 columns]

# %%
#Clean with all records minus some advanced team stats 
df_all_teams = df_3
print(len(df_all_teams))
# Out:
# 129

# %%
df_final = df_clean
df_final.describe()
# Out:
#            TotalPay      Bowl W  ...         GSR         FGR
# count  1.100000e+02  110.000000  ...  110.000000  110.000000
# mean   2.520967e+06    2.990909  ...   80.328919   63.224655
# std    1.954829e+06    3.393181  ...    8.778692   11.448118
# min    0.000000e+00    0.000000  ...   51.000000   32.000000
# 25%    8.068875e+05    0.000000  ...   75.000000   57.250000
# 50%    2.000000e+06    2.000000  ...   80.590551   63.000000
# 75%    3.738494e+06    5.000000  ...   88.000000   69.750000
# max    8.307000e+06   17.000000  ...   97.000000   93.000000
#
# [8 rows x 50 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## Log Transformation might be useful.... tested in modeling without successful accuracy gains.

# %%
# Total Pay Distribution.
# We'll plot a histogram to gauge whether TotalPay follows a normal distribution or is skewed. 
sns.distplot(df_final.TotalPay, bins = 5)
_ = plt.title('Salary Distribution')
_ = plt.xlabel('Salary')
_ = plt.ylabel('Distribution')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### This one started off as a good idea in my head...

# %%
corrMatrix = df_final.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
# SOS and Total Pay
fig7= sns.lmplot(x='SOS', y='TotalPay', data=df_final, hue='Conference', fit_reg=False)
sns.regplot(x='SOS', y='TotalPay', data=df_final, scatter=False, ax=fig7.axes[0,0])
_ = plt.xlabel('Strenght of Schedule (SOS)')
_ = plt.ylabel('Total Pay')
_ = plt.title('Total Pay by SOS')
plt.show()

# %%
# Prgoram Revenue and Total Pay
fig8= sns.lmplot(x='Program Revenue', y='TotalPay', data=df_final, hue='Conference', fit_reg=False)
sns.regplot(x='Program Revenue', y='TotalPay', data=df_final, scatter=False, ax=fig8.axes[0,0])
_ = plt.xlabel('Program Revenue')
_ = plt.ylabel('Total Pay')
_ = plt.title('Total Pay by Program Revenue')
plt.show()

# %%
# Does defense win championships... not sure... but does it lead to coach $$$$-YES
fig9= sns.lmplot(x='PPG Def', y='TotalPay', data=df_final, hue='Conference', fit_reg=False)
sns.regplot(x='PPG Def', y='TotalPay', data=df_final, scatter=False, ax=fig9.axes[0,0])
_ = plt.xlabel('PPG Def')
_ = plt.ylabel('Total Pay')
_ = plt.title('Total Pay by PPG Def')
plt.show()

# %%
# Ttoal Pay and Stadium Capacity
fig11= sns.lmplot(x='Capacity', y='TotalPay', data=df_final, hue='Conference', fit_reg=False)
sns.regplot(x='Capacity', y='TotalPay', data=df_final, scatter=False, ax=fig11.axes[0,0])
_ = plt.xlabel('Stadium Capacity')
_ = plt.ylabel('Total Pay')
_ = plt.title('Total Pay by Stadium Capacity')
plt.show()

# %%
# Do graduation rates impact $$$$...ehhhh not really...
fig10= sns.lmplot(x='GSR', y='TotalPay', data=df_final, hue='Conference', fit_reg=False)
sns.regplot(x='GSR', y='TotalPay', data=df_final, scatter=False, ax=fig10.axes[0,0])
_ = plt.xlabel('GSR')
_ = plt.ylabel('Total Pay')
_ = plt.title('Total Pay by GSR')
plt.show()

# %% [markdown]
# ## Dummy Coded Conference

# %%
#df_final['Conference2'] =df_final['Conference'].astype('category').cat.codes
df_final = pd.get_dummies(df_final, prefix='', prefix_sep='', 
                            columns=['Conference'])

# %%
len(df_final.columns)
# Out:
# 64

# %%
corr_matrix = df_final.corr()
print(corr_matrix["TotalPay"].sort_values(ascending=False))
# Out:
# TotalPay           1.000000
# Program Revenue    0.847675
# Capacity           0.836794
# SOS                0.761419
# SRS                0.722728
#                      ...
# Overall L         -0.429875
# PPG Def           -0.435971
# AP Rank           -0.550661
# AP Pre            -0.673070
# AP High           -0.691590
# Name: TotalPay, Length: 61, dtype: float64

# %%
# make sure to specify some features that you might want to focus on or the plots might be too big
#!pip install pandas.tools
from pandas.plotting import scatter_matrix
attributes = ["Capacity","SOS","SRS"]
scatter_matrix(df_final[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ae2e9c790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ae2e68950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada33ed50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada2fd310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada2b5890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada269e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada22b3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada262950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3ada1ea690>]],
#       dtype=object)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Model 1: Bring the Noise (Everything)
#
# 1.   All variables
# 2.   Nonsense (multicollinearity)

# %%
df_model = df_final[df_final.columns.difference(['Coach'])]
#feature_names= df_model.loc[:, df_model.columns != 'TotalPay']
#feature_names= feature_names.loc[:, feature_names.columns != 'School']
features = df_model.columns.values.tolist()

# %%
features.remove('TotalPay')
features.remove('School')
features.remove('State')

# %%
# Select the feature_names variables and the target variable. This will facilitate the creation of the 
# training and testing sets. 
target_name = ['TotalPay']
#print(target_name)
# We'll now take out the validation set. 
validation = df_model[df_model['School']=='Syracuse']
df_model2 = df_model[df_model['School']!='Syracuse']
len(df_model2)
# Out:
# 109

# %%
# Build training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_model2[features], df_model2[target_name], test_size=0.33, random_state=19)

# %%
# Builds the model
model = sm.OLS(y_train, X_train)

# Fits the model
results = model.fit()

# Model results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TotalPay   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     16.11
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):           3.04e-07
# Time:                        12:34:21   Log-Likelihood:                -1008.8
# No. Observations:                  73   AIC:                             2134.
# Df Residuals:                      15   BIC:                             2266.
# Df Model:                          57
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# AAC                 1.182e+07   1.64e+07      0.721      0.482   -2.31e+07    4.68e+07
# ACC                  1.24e+07   1.63e+07      0.760      0.459   -2.24e+07    4.72e+07
# AP High            -1.001e+04   1.32e+04     -0.756      0.461   -3.82e+04    1.82e+04
# AP Pre             -4.449e+04   1.78e+04     -2.494      0.025   -8.25e+04   -6462.943
# AP Rank             6.605e+04   1.67e+04      3.960      0.001    3.05e+04    1.02e+05
# Age                -1.745e+04   1.66e+04     -1.050      0.311   -5.29e+04     1.8e+04
# Big 12              1.262e+07   1.65e+07      0.765      0.456   -2.25e+07    4.78e+07
# Big Ten             1.263e+07   1.65e+07      0.764      0.457   -2.26e+07    4.79e+07
# Bowl W              3.446e+04   7.08e+04      0.487      0.633   -1.16e+05    1.85e+05
# C-USA               1.087e+07   1.61e+07      0.675      0.510   -2.34e+07    4.52e+07
# Capacity               4.8739     11.994      0.406      0.690     -20.691      30.439
# Career L            7519.4149   1.56e+04      0.483      0.636   -2.57e+04    4.07e+04
# Career W            2.586e+04   7225.731      3.579      0.003    1.05e+04    4.13e+04
# Career Win %        1.826e+06   2.09e+06      0.875      0.395   -2.62e+06    6.27e+06
# Career Yrs.        -1.325e+05   5.29e+04     -2.504      0.024   -2.45e+05   -1.97e+04
# Conference L        1.804e+05   1.02e+05      1.763      0.098   -3.77e+04    3.99e+05
# Conference Pct     -4.159e+06      3e+06     -1.384      0.187   -1.06e+07    2.25e+06
# Conference W        5.305e+05   3.07e+05      1.728      0.105   -1.24e+05    1.18e+06
# FGR                -8374.5282   1.74e+04     -0.482      0.637   -4.54e+04    2.87e+04
# First DownsPass    -3.382e+05   1.66e+06     -0.204      0.841   -3.87e+06     3.2e+06
# First DownsPen      9.646e+04   1.75e+06      0.055      0.957   -3.63e+06    3.83e+06
# First DownsRush     -4.96e+05   1.68e+06     -0.295      0.772   -4.07e+06    3.08e+06
# First DownsTot      4.279e+05   1.67e+06      0.256      0.801   -3.13e+06    3.99e+06
# GSR                 -2.87e+04   2.42e+04     -1.185      0.255   -8.03e+04    2.29e+04
# Ind.                1.152e-06   5.28e-07      2.182      0.045    2.67e-08    2.28e-06
# MAC                 1.147e+07   1.62e+07      0.708      0.490   -2.31e+07     4.6e+07
# Mt. West            1.292e+07   1.63e+07      0.791      0.441   -2.19e+07    4.77e+07
# Overall L          -9.536e+05   6.35e+05     -1.501      0.154   -2.31e+06    4.01e+05
# Overall Pct        -3.476e+07   1.29e+07     -2.705      0.016   -6.22e+07   -7.36e+06
# Overall W           1.942e+06   5.02e+05      3.868      0.002    8.72e+05    3.01e+06
# PPG Def             1.721e+05   7.96e+04      2.160      0.047    2299.528    3.42e+05
# PPG Off            -1.445e+05   5.46e+04     -2.644      0.018   -2.61e+05    -2.8e+04
# Pac-12              1.152e+07   1.65e+07      0.697      0.497   -2.37e+07    4.67e+07
# Passing Cmp         8.671e+05   3.65e+05      2.373      0.031    8.83e+04    1.65e+06
# PassingAtt         -4.357e+06   2.29e+06     -1.905      0.076   -9.23e+06    5.19e+05
# PassingPct         -3.073e+05   9.22e+04     -3.333      0.005   -5.04e+05   -1.11e+05
# PassingTD           4.258e+05   6.75e+05      0.631      0.537   -1.01e+06    1.86e+06
# PassingYds         -9.749e+06   3.71e+06     -2.626      0.019   -1.77e+07   -1.84e+06
# PenaltiesNo.       -7.129e+05   4.34e+05     -1.644      0.121   -1.64e+06    2.11e+05
# PenaltiesYds        7.739e+04   4.41e+04      1.754      0.100   -1.66e+04    1.71e+05
# Program Revenue       -0.0053      0.006     -0.894      0.386      -0.018       0.007
# Pts                -1.445e+05   5.46e+04     -2.644      0.018   -2.61e+05    -2.8e+04
# RushingAtt          -3.35e+06   2.23e+06     -1.501      0.154   -8.11e+06    1.41e+06
# RushingAvg          4.818e+06   1.17e+06      4.132      0.001    2.33e+06     7.3e+06
# RushingTD            2.67e+06   7.45e+05      3.584      0.003    1.08e+06    4.26e+06
# RushingYds         -9.885e+06   3.73e+06     -2.653      0.018   -1.78e+07   -1.94e+06
# SEC                 1.488e+07   1.67e+07      0.894      0.386   -2.06e+07    5.04e+07
# SOS                -4.908e+04   1.42e+05     -0.345      0.735   -3.52e+05    2.54e+05
# SRS                 2.148e+05   1.27e+05      1.692      0.111   -5.57e+04    4.85e+05
# School L           -1.716e+04   2.32e+04     -0.741      0.470   -6.65e+04    3.22e+04
# School W            4858.8945   2.38e+04      0.204      0.841   -4.59e+04    5.56e+04
# School Win %       -8.694e+05   1.62e+06     -0.535      0.600   -4.33e+06    2.59e+06
# School Yrs.         3.039e+04   2.17e+05      0.140      0.891   -4.33e+05    4.94e+05
# Sun Belt            1.384e+07   1.61e+07      0.858      0.404   -2.05e+07    4.82e+07
# Total OffenseAvg   -8.804e+05   2.46e+06     -0.358      0.726   -6.13e+06    4.37e+06
# Total OffensePlays  3.859e+06   2.23e+06      1.734      0.103   -8.85e+05     8.6e+06
# Total OffenseYds    9.757e+06   3.71e+06      2.627      0.019    1.84e+06    1.77e+07
# TurnoversFum       -8.769e+04   2.82e+06     -0.031      0.976   -6.11e+06    5.93e+06
# TurnoversInt        1.053e+06   2.76e+06      0.382      0.708   -4.82e+06    6.93e+06
# TurnoversTot        1.637e+04   2.79e+06      0.006      0.995   -5.93e+06    5.96e+06
# ==============================================================================
# Omnibus:                        0.155   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.925   Jarque-Bera (JB):                0.267
# Skew:                           0.102   Prob(JB):                        0.875
# Kurtosis:                       2.785   Cond. No.                     1.01e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.03e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Predict salaries for first model
prediction = results.predict(X_test)
prediction = pd.Series(prediction)

prediction_results = pd.concat([y_test, prediction], axis=1, ignore_index=False)
prediction_results.columns = ['TotalPay Actual', 'TotalPay Predicted']

print('Model 1 R-squared: ', r2_score(prediction_results['TotalPay Actual'], 
                                      prediction_results['TotalPay Predicted']))
print('Model 1 RMSE: ', np.sqrt(mean_squared_error(prediction_results['TotalPay Actual'], 
                                                   prediction_results['TotalPay Predicted'])))
print('Model 1 MAE: ', mean_absolute_error(prediction_results['TotalPay Actual'], 
                                           prediction_results['TotalPay Predicted']))
sns.scatterplot(x='TotalPay Actual', y='TotalPay Predicted', data=prediction_results)
_ = plt.title('Model 1 - Actual vs Predicted Salaries')
_ = plt.xlabel('Actual Salary')
_ = plt.ylabel('Predicted Salary')
plt.show()
# Out:
# Model 1 R-squared:  -0.8836764231860916
# Model 1 RMSE:  2791592.1738209086
# Model 1 MAE:  1933264.7288192776

# %% [markdown]
# ## Model 2 Top Correlations Only

# %%
features2 = ['Capacity','SOS','SRS','Bowl W','School Win %','Program Revenue']
# Build training and testing sets
X_train2, X_test2, y_train2, y_test2 = train_test_split(df_model2[features2], df_model2[target_name], 
                                                   test_size=0.33, random_state=19)

# %%
# Builds the model
model2 = sm.OLS(y_train2, X_train2)

# Fits the model
results2 = model2.fit()

# Model results
print(results2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TotalPay   R-squared (uncentered):                   0.948
# Model:                            OLS   Adj. R-squared (uncentered):              0.943
# Method:                 Least Squares   F-statistic:                              201.7
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    7.16e-41
# Time:                        12:34:22   Log-Likelihood:                         -1088.7
# No. Observations:                  73   AIC:                                      2189.
# Df Residuals:                      67   BIC:                                      2203.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Capacity           10.2181      7.157      1.428      0.158      -4.067      24.503
# SOS              8.439e+04   2.89e+04      2.922      0.005    2.67e+04    1.42e+05
# SRS               2.77e+04   1.21e+04      2.288      0.025    3532.270    5.19e+04
# Bowl W           8.345e+04   3.63e+04      2.299      0.025     1.1e+04    1.56e+05
# School Win %      9.01e+05   5.22e+05      1.725      0.089   -1.42e+05    1.94e+06
# Program Revenue     0.0141      0.004      3.997      0.000       0.007       0.021
# ==============================================================================
# Omnibus:                        1.385   Durbin-Watson:                   1.624
# Prob(Omnibus):                  0.500   Jarque-Bera (JB):                0.758
# Skew:                           0.106   Prob(JB):                        0.685
# Kurtosis:                       3.452   Cond. No.                     5.87e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.87e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Predict salaries for second model
prediction2 = results2.predict(X_test2)
prediction2 = pd.Series(prediction2)

prediction_results2 = pd.concat([y_test2, prediction2], axis=1, ignore_index=False)
prediction_results2.columns = ['TotalPay Actual', 'TotalPay Predicted']

print('Model 2 R-squared: ', r2_score(prediction_results2['TotalPay Actual'], 
                                      prediction_results2['TotalPay Predicted']))
print('Model 2 RMSE: ', np.sqrt(mean_squared_error(prediction_results2['TotalPay Actual'], 
                                                   prediction_results2['TotalPay Predicted'])))
print('Model 2 MAE: ', mean_absolute_error(prediction_results2['TotalPay Actual'], 
                                           prediction_results2['TotalPay Predicted']))
sns.scatterplot(x='TotalPay Actual', y='TotalPay Predicted', data=prediction_results2)
_ = plt.title('Model 2 - Actual vs Predicted Salaries')
_ = plt.xlabel('Actual Salary')
_ = plt.ylabel('Predicted Salary')
plt.show()
# Out:
# Model 2 R-squared:  0.8123601101462732
# Model 2 RMSE:  881072.0121053094
# Model 2 MAE:  710496.8217966057

# %% [markdown]
# ## Model 3 Remove Noise More Variables (super over fit)

# %%
features.remove('TurnoversFum')
features.remove('TurnoversInt')
features.remove('First DownsPass')
features.remove('First DownsPen')
features.remove('First DownsRush')
features.remove('Career Win %')
features.remove('PassingTD')
features.remove('School L')
features.remove('School W')
features.remove('School Yrs.')
features.remove('Bowl W')
features.remove('Career L')
features.remove('Conference L')
features.remove('Total OffenseAvg')
features.remove('Overall L')
features.remove('First DownsTot')
features.remove('AAC')
features.remove('ACC')
features.remove('Big 12')
features.remove('Big Ten')
features.remove('Mt. West')
features.remove('Ind.')
features.remove('SOS')

# %%
# Build training and testing sets
X_train3, X_test3, y_train3, y_test3 = train_test_split(df_model2[features], df_model2[target_name], test_size=0.33, random_state=19)

# %%
# Builds the model
model3 = sm.OLS(y_train3, X_train3)

# Fits the model
results3 = model3.fit()

# Model results
print(results3.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TotalPay   R-squared (uncentered):                   0.989
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              91.48
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    3.67e-27
# Time:                        12:34:22   Log-Likelihood:                         -1032.0
# No. Observations:                  73   AIC:                                      2136.
# Df Residuals:                      37   BIC:                                      2219.
# Df Model:                          36
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# AP High            -1.358e+04   7641.281     -1.777      0.084   -2.91e+04    1907.116
# AP Pre             -2.168e+04   7932.577     -2.732      0.010   -3.77e+04   -5602.663
# AP Rank             4.282e+04   8039.522      5.326      0.000    2.65e+04    5.91e+04
# Age                -2.753e+04   9952.544     -2.766      0.009   -4.77e+04   -7365.418
# C-USA              -9.548e+05   3.48e+05     -2.741      0.009   -1.66e+06   -2.49e+05
# Capacity               9.5867      7.192      1.333      0.191      -4.987      24.160
# Career W             2.67e+04   4084.808      6.537      0.000    1.84e+04     3.5e+04
# Career Yrs.        -1.123e+05   2.53e+04     -4.433      0.000   -1.64e+05    -6.1e+04
# Conference Pct     -3.628e+06   1.73e+06     -2.102      0.042   -7.12e+06   -1.32e+05
# Conference W        3.941e+05   1.68e+05      2.341      0.025     5.3e+04    7.35e+05
# FGR                -4070.3956   9363.062     -0.435      0.666    -2.3e+04    1.49e+04
# GSR                -1.374e+04   1.17e+04     -1.171      0.249   -3.75e+04       1e+04
# MAC                -4.666e+05   3.47e+05     -1.346      0.187   -1.17e+06    2.36e+05
# Overall Pct        -1.591e+07   3.63e+06     -4.381      0.000   -2.33e+07   -8.55e+06
# Overall W           1.221e+06   2.46e+05      4.964      0.000    7.23e+05    1.72e+06
# PPG Def             1.222e+05   2.52e+04      4.845      0.000    7.11e+04    1.73e+05
# PPG Off             -7.28e+04   1.82e+04     -4.008      0.000    -1.1e+05    -3.6e+04
# Pac-12             -6.197e+05   2.68e+05     -2.314      0.026   -1.16e+06    -7.7e+04
# Passing Cmp         5.697e+05    1.6e+05      3.554      0.001    2.45e+05    8.94e+05
# PassingAtt         -4.087e+06   1.36e+06     -3.008      0.005   -6.84e+06   -1.33e+06
# PassingPct         -2.001e+05   3.93e+04     -5.092      0.000    -2.8e+05    -1.2e+05
# PassingYds          -5.15e+06   1.52e+06     -3.385      0.002   -8.23e+06   -2.07e+06
# PenaltiesNo.       -6.915e+05   2.63e+05     -2.634      0.012   -1.22e+06   -1.59e+05
# PenaltiesYds        7.108e+04   2.73e+04      2.608      0.013    1.59e+04    1.26e+05
# Program Revenue       -0.0003      0.003     -0.109      0.914      -0.007       0.006
# Pts                 -7.28e+04   1.82e+04     -4.008      0.000    -1.1e+05    -3.6e+04
# RushingAtt         -3.553e+06   1.37e+06     -2.598      0.013   -6.32e+06   -7.82e+05
# RushingAvg          3.015e+06   5.93e+05      5.084      0.000    1.81e+06    4.22e+06
# RushingTD           1.591e+06   3.08e+05      5.163      0.000    9.67e+05    2.22e+06
# RushingYds          -5.23e+06   1.52e+06     -3.430      0.001   -8.32e+06   -2.14e+06
# SEC                 1.905e+06   2.86e+05      6.651      0.000    1.32e+06    2.49e+06
# SRS                 1.677e+05   2.78e+04      6.023      0.000    1.11e+05    2.24e+05
# School Win %        1.372e+06   6.69e+05      2.051      0.047    1.66e+04    2.73e+06
# Sun Belt            1.538e+06   4.15e+05      3.709      0.001    6.98e+05    2.38e+06
# Total OffensePlays  3.866e+06   1.35e+06      2.857      0.007    1.12e+06    6.61e+06
# Total OffenseYds    5.143e+06   1.52e+06      3.380      0.002    2.06e+06    8.23e+06
# TurnoversTot        4.122e+05   1.88e+05      2.192      0.035    3.12e+04    7.93e+05
# ==============================================================================
# Omnibus:                        1.607   Durbin-Watson:                   1.543
# Prob(Omnibus):                  0.448   Jarque-Bera (JB):                1.633
# Skew:                           0.326   Prob(JB):                        0.442
# Kurtosis:                       2.665   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.66e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Predict salaries for second model
prediction3 = results3.predict(X_test3)
prediction2 = pd.Series(prediction3)

prediction_results3 = pd.concat([y_test3, prediction3], axis=1, ignore_index=False)
prediction_results3.columns = ['TotalPay Actual', 'TotalPay Predicted']

print('Model 3 R-squared: ', r2_score(prediction_results3['TotalPay Actual'], 
                                      prediction_results3['TotalPay Predicted']))
print('Model 3 RMSE: ', np.sqrt(mean_squared_error(prediction_results3['TotalPay Actual'], 
                                                   prediction_results3['TotalPay Predicted'])))
print('Model 3 MAE: ', mean_absolute_error(prediction_results3['TotalPay Actual'], 
                                           prediction_results3['TotalPay Predicted']))
sns.scatterplot(x='TotalPay Actual', y='TotalPay Predicted', data=prediction_results3)
_ = plt.title('Model 3 - Actual vs Predicted Salaries')
_ = plt.xlabel('Actual Salary')
_ = plt.ylabel('Predicted Salary')
plt.show()
# Out:
# Model 3 R-squared:  0.5074455188990388
# Model 3 RMSE:  1427499.4788223312
# Model 3 MAE:  1118358.0231524908

# %% [markdown]
# ## PCA
#
# *   Explored but more work can be done

# %%
from sklearn.preprocessing import StandardScaler
# Separating out the features
x = df_model2.loc[:, features].values
# Separating out the target
y = df_model2.loc[:,target_name].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# Standardizing the target
y = StandardScaler().fit_transform(y)
print(len(y))
# Out:
# 109

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])
print(principalDf)
print(df_model2[['TotalPay']])
# Out:
#      principal component 1  principal component 2  principal component 3
# 0                 0.429728               5.766268              -2.701460
# 1                -1.399567               0.875860               0.115216
# 2                 8.312512               3.076437               2.856683
# 3                 1.461249               0.154127              -2.942658
# 4                 2.858821               1.954472              -3.241067
# ..                     ...                    ...                    ...
# 104               0.755434              -2.608136               0.029408
# 105              -3.014480              -4.963857              -0.144619
# 106              -0.215453               1.506047              -2.457924
# 107               6.017009               1.288361               1.646814
# 108              -2.200555               1.951922               2.286967
#
# [109 rows x 3 columns]
#       TotalPay
# 0     885000.0
# 1     412500.0
# 2    8307000.0
# 4     712500.0
# 5    2000000.0
# ..         ...
# 124  3617500.0
# 125   805850.0
# 126   800000.0
# 127  3750000.0
# 128  1412000.0
#
# [109 rows x 1 columns]

# %%
principalDf[["y"]] = y
finalDf = principalDf
finalDf.isnull().sum()
print(finalDf)
# Out:
#      principal component 1  ...         y
# 0                 0.429728  ... -0.837461
# 1                -1.399567  ... -1.079175
# 2                 8.312512  ...  2.959356
# 3                 1.461249  ... -0.925706
# 4                 2.858821  ... -0.267069
# ..                     ...  ...       ...
# 104               0.755434  ...  0.560383
# 105              -3.014480  ... -0.877952
# 106              -0.215453  ... -0.880944
# 107               6.017009  ...  0.628165
# 108              -2.200555  ... -0.567868
#
# [109 rows x 4 columns]

# %%
#finalDf = pd.concat([principalDf, df_model2[['TotalPay']]], axis = 1)
#print(finalDf.tail())
#finalDf.isnull().sum()

# %%
featuresPCA = ['principal component 1', 'principal component 2','principal component 3']
# Build training and testing sets
X_trainPCA, X_testPCA, y_trainPCA, y_testPCA = train_test_split(finalDf[featuresPCA], finalDf["y"], 
                                                   test_size=0.33, random_state=19)

# %%
# Builds the model
modelPCA = sm.OLS(y_trainPCA, X_trainPCA)

# Fits the model
resultsPCA = modelPCA.fit()

# Model results
print(resultsPCA.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.728
# Model:                            OLS   Adj. R-squared (uncentered):              0.717
# Method:                 Least Squares   F-statistic:                              62.52
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    9.14e-20
# Time:                        12:34:22   Log-Likelihood:                         -54.514
# No. Observations:                  73   AIC:                                      115.0
# Df Residuals:                      70   BIC:                                      121.9
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# principal component 1     0.1787      0.019      9.434      0.000       0.141       0.217
# principal component 2     0.0126      0.026      0.488      0.627      -0.039       0.064
# principal component 3     0.3153      0.035      8.991      0.000       0.245       0.385
# ==============================================================================
# Omnibus:                        3.781   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                3.752
# Skew:                           0.182   Prob(JB):                        0.153
# Kurtosis:                       4.049   Cond. No.                         1.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Predict Syracuse Salary

# %%
validation
# Out:
#      AAC  ACC  AP High  ...  TurnoversFum  TurnoversInt  TurnoversTot
# 102    0    1     50.0  ...           0.7           1.3           2.0
#
# [1 rows x 63 columns]

# %%
valid_predict = results2.predict(validation[features2])
print(valid_predict-validation['TotalPay'])
# Print results 
print('Actual Salary: ', validation['TotalPay'])
print('Model Prediction: %s' % np.round(valid_predict, 0))
print('Difference: %s' % np.round(valid_predict-validation['TotalPay']))
# Out:
# 102   -211140.018485
# dtype: float64
# Actual Salary:  102    2401206.0
# Name: TotalPay, dtype: float64
# Model Prediction: 102    2190066.0
# dtype: float64
# Difference: 102   -211140.0
# dtype: float64

# %%
#from statsmodels.sandbox.regression.predstd import wls_prediction_std
#prstd, iv_l, iv_u = wls_prediction_std(valid_predict)
#prstd

# %% [markdown]
# ## Fit a hierarchical model based on conference
#
# *   Model 2 features add signifiacnt value

# %%
featuresConf = ['AAC','ACC','C-USA','MAC','Ind.','Mt. West','Pac-12','SEC','Sun Belt']
# Build training and testing sets
X_trainConf, X_testConf, y_trainConf, y_testConf = train_test_split(df_model2[featuresConf], df_model2[target_name], 
                                                   test_size=0.33, random_state=19)
# Builds the model
modelConf = sm.OLS(y_trainConf, X_trainConf)

# Fits the model
resultsConf = modelConf.fit()

# Model results
print(resultsConf.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TotalPay   R-squared (uncentered):                   0.467
# Model:                            OLS   Adj. R-squared (uncentered):              0.401
# Method:                 Least Squares   F-statistic:                              7.106
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    1.04e-06
# Time:                        12:34:23   Log-Likelihood:                         -1173.3
# No. Observations:                  73   AIC:                                      2363.
# Df Residuals:                      65   BIC:                                      2381.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AAC         1.733e+06   8.67e+05      1.999      0.050    1595.200    3.46e+06
# ACC         3.155e+06      1e+06      3.152      0.002    1.16e+06    5.15e+06
# C-USA       7.084e+05    1.1e+06      0.646      0.520   -1.48e+06     2.9e+06
# MAC         6.203e+05      1e+06      0.620      0.538   -1.38e+06    2.62e+06
# Ind.                0          0        nan        nan           0           0
# Mt. West    1.002e+06   8.17e+05      1.226      0.224    -6.3e+05    2.63e+06
# Pac-12      3.097e+06   9.27e+05      3.342      0.001    1.25e+06    4.95e+06
# SEC         4.406e+06   8.17e+05      5.390      0.000    2.77e+06    6.04e+06
# Sun Belt    6.261e+05      1e+06      0.625      0.534   -1.37e+06    2.63e+06
# ==============================================================================
# Omnibus:                       19.777   Durbin-Watson:                   1.631
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.589
# Skew:                           1.309   Prob(JB):                     4.58e-06
# Kurtosis:                       4.109   Cond. No.                          inf
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1755: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1294: RuntimeWarning:
#
# invalid value encountered in true_divide

# %%
featuresConf2 = ['AAC','ACC','C-USA','MAC','Ind.','Mt. West','Pac-12','SEC','Sun Belt','Capacity','SOS','SRS','Bowl W','School Win %','Program Revenue']
# Build training and testing sets
X_trainConf2, X_testConf2, y_trainConf2, y_testConf2 = train_test_split(df_model2[featuresConf2], df_model2[target_name], 
                                                   test_size=0.33, random_state=19)
# Builds the model
modelConf2 = sm.OLS(y_trainConf2, X_trainConf2)

# Fits the model
resultsConf2 = modelConf2.fit()

# Model results
print(resultsConf2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TotalPay   R-squared (uncentered):                   0.952
# Model:                            OLS   Adj. R-squared (uncentered):              0.941
# Method:                 Least Squares   F-statistic:                              83.81
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    1.55e-33
# Time:                        12:34:23   Log-Likelihood:                         -1085.4
# No. Observations:                  73   AIC:                                      2199.
# Df Residuals:                      59   BIC:                                      2231.
# Df Model:                          14
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# AAC              4445.1698   4.48e+05      0.010      0.992   -8.92e+05       9e+05
# ACC              1.025e+05   3.63e+05      0.282      0.779   -6.25e+05     8.3e+05
# C-USA           -4.151e+05   7.01e+05     -0.592      0.556   -1.82e+06    9.87e+05
# MAC             -2.918e+05   5.88e+05     -0.496      0.622   -1.47e+06    8.85e+05
# Ind.             1.905e-10   3.64e-10      0.523      0.603   -5.38e-10    9.19e-10
# Mt. West        -5.855e+05   5.57e+05     -1.052      0.297    -1.7e+06    5.28e+05
# Pac-12           -2.51e+04   3.59e+05     -0.070      0.944   -7.43e+05    6.93e+05
# SEC              4.277e+05   3.44e+05      1.243      0.219   -2.61e+05    1.12e+06
# Sun Belt        -1.634e+05    7.7e+05     -0.212      0.833    -1.7e+06    1.38e+06
# Capacity           12.2322      8.904      1.374      0.175      -5.584      30.048
# SOS              5.929e+04   5.33e+04      1.112      0.270   -4.74e+04    1.66e+05
# SRS               2.39e+04   1.42e+04      1.684      0.098   -4505.995    5.23e+04
# Bowl W           8.755e+04   3.87e+04      2.263      0.027    1.01e+04    1.65e+05
# School Win %     1.183e+06   7.29e+05      1.624      0.110   -2.75e+05    2.64e+06
# Program Revenue     0.0120      0.004      2.813      0.007       0.003       0.021
# ==============================================================================
# Omnibus:                        2.956   Durbin-Watson:                   1.626
# Prob(Omnibus):                  0.228   Jarque-Bera (JB):                2.752
# Skew:                          -0.026   Prob(JB):                        0.253
# Kurtosis:                       3.950   Cond. No.                     4.21e+24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.08e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from statsmodels.stats.anova import anova_lm
anova_lm(resultsConf,resultsConf2)
# Out:
#    df_resid           ssr  df_diff       ss_diff          F        Pr(>F)
# 0      65.0  3.907523e+14      0.0           NaN        NaN           NaN
# 1      59.0  3.506829e+13      6.0  3.556840e+14  99.735659  5.207145e-29

# %% [markdown]
# ## What would his salary be if we were still in the Big East? What if we went to the Big Ten?
#
# *   Big East would not factor into this model as it is not included in the originial dataset
# *   Replacing ACC 'Yes' with Big Ten 'Yes'
#
# Pay-cut would be needed :)

# %%
validation.at[102, 'ACC'] = 0
validation.at[102, 'Big Ten'] = 1

# %%
validation
# Out:
#      AAC  ACC  AP High  ...  TurnoversFum  TurnoversInt  TurnoversTot
# 102    0    0     50.0  ...           0.7           1.3           2.0
#
# [1 rows x 63 columns]

# %%
valid_predict_Big10 = resultsConf2.predict(validation[featuresConf2])
print(valid_predict-validation['TotalPay'])
# Print results 
print('Actual Salary: ', validation['TotalPay'])
print('Model Prediction: %s' % np.round(valid_predict_Big10, 0))
print('Difference if Big 10: %s' % np.round(valid_predict_Big10-valid_predict))
# Out:
# 102   -211140.018485
# dtype: float64
# Actual Salary:  102    2401206.0
# Name: TotalPay, dtype: float64
# Model Prediction: 102    2167572.0
# dtype: float64
# Difference if Big 10: 102   -22494.0
# dtype: float64

# %% [markdown]
# # What schools did we drop from our data and why?
#
# *   The following 19 schools were dropped due to many missing values (including key features)

# %%
dropped=df_6[df_6.isna().any(axis=1)]
dropped
# Out:
#       TotalPay Conference            Coach  ...  State        GSR     FGR
# 3     900000.0      C-USA       Bill Clark  ...     AL  73.000000  47.000
# 9     932521.0       Ind.      Jeff Monken  ...     NY  80.181102  62.904
# 15    437228.0        MAC       Mike Jinks  ...     OH  78.000000  68.000
# 16         0.0       Ind.    Kalani Sitake  ...     UT  70.000000  40.000
# 19   1700000.0        AAC      Josh Heupel  ...     FL  81.000000  65.000
# 50    947281.0       Ind.      Turner Gill  ...     VA  65.000000  55.000
# 52    850000.0   Sun Belt     Billy Napier  ...     LA  85.000000  68.000
# 58    500000.0       Ind.     Mark Whipple  ...     MA  67.000000  51.000
# 60   4058061.0        ACC       Mark Richt  ...     FL  76.000000  42.000
# 61    524826.0        MAC     Chuck Martin  ...     OH  89.000000  72.000
# 64    803004.0      C-USA  Rick Stockstill  ...     TN  95.000000  70.000
# 66   3000000.0        SEC        Matt Luke  ...     MS  81.000000  68.000
# 72    600000.0   Mt. West     Tony Sanchez  ...     NV  69.000000  61.000
# 80   2129638.0       Ind.      Brian Kelly  ...     IN  91.000000  85.000
# 89   3017718.0        ACC     Pat Narduzzi  ...     PA  86.000000  56.000
# 98   2625965.0     Pac-12      Clay Helton  ...     CA  82.000000  62.000
# 99         0.0        AAC      Sonny Dykes  ...     TX  75.000000  64.000
# 109   700000.0      C-USA       Dana Dimel  ...     TX  81.000000  62.000
# 110  1100000.0      C-USA     Frank Wilson  ...     TX  83.000000  61.000
#
# [19 rows x 54 columns]

# %%
print(dropped["School"])
print(len(dropped["School"]))
# Out:
# 3                   Alabama at Birmingham
# 9                                    Army
# 15                          Bowling Green
# 16                          Brigham Young
# 19                        Central Florida
# 50                                Liberty
# 52                    Louisiana-Lafayette
# 58                          Massachusetts
# 60          University of Miami (Florida)
# 61                           Miami (Ohio)
# 64                       Middle Tennessee
# 66                            Mississippi
# 72                       Nevada-Las Vegas
# 80                             Notre Dame
# 89                             Pittsburgh
# 98                    Southern California
# 99                     Southern Methodist
# 109                         Texas-El Paso
# 110    University of Texas at San Antonio
# Name: School, dtype: object
# 19

# %% [markdown]
# # What effect does graduation rate have on the projected salary?
#
# *   Not much... weak correlations (GSR slightly positive)
# *   Do not add incremental predictive validity above more prominent features

# %%
df_final["TotalPay"].corr(df_final["GSR"])
# Out:
# 0.12974907644966235

# %%
df_final["TotalPay"].corr(df_final["FGR"])
# Out:
# -0.03585670078919374

# %% [markdown]
# # How good is our model?
#
# *   Pretty solid with room for growth (more features, more complex models)
# *   Some overfitting (0.94 Adj. R sq. in training, 0.81 in test)

# %%
# Model results
print(results2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TotalPay   R-squared (uncentered):                   0.948
# Model:                            OLS   Adj. R-squared (uncentered):              0.943
# Method:                 Least Squares   F-statistic:                              201.7
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    7.16e-41
# Time:                        12:34:23   Log-Likelihood:                         -1088.7
# No. Observations:                  73   AIC:                                      2189.
# Df Residuals:                      67   BIC:                                      2203.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Capacity           10.2181      7.157      1.428      0.158      -4.067      24.503
# SOS              8.439e+04   2.89e+04      2.922      0.005    2.67e+04    1.42e+05
# SRS               2.77e+04   1.21e+04      2.288      0.025    3532.270    5.19e+04
# Bowl W           8.345e+04   3.63e+04      2.299      0.025     1.1e+04    1.56e+05
# School Win %      9.01e+05   5.22e+05      1.725      0.089   -1.42e+05    1.94e+06
# Program Revenue     0.0141      0.004      3.997      0.000       0.007       0.021
# ==============================================================================
# Omnibus:                        1.385   Durbin-Watson:                   1.624
# Prob(Omnibus):                  0.500   Jarque-Bera (JB):                0.758
# Skew:                           0.106   Prob(JB):                        0.685
# Kurtosis:                       3.452   Cond. No.                     5.87e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.87e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print('Model 2 R-squared: ', r2_score(prediction_results2['TotalPay Actual'], 
                                      prediction_results2['TotalPay Predicted']))
print('Model 2 RMSE: ', np.sqrt(mean_squared_error(prediction_results2['TotalPay Actual'], 
                                                   prediction_results2['TotalPay Predicted'])))
print('Model 2 MAE: ', mean_absolute_error(prediction_results2['TotalPay Actual'], 
                                           prediction_results2['TotalPay Predicted']))
sns.scatterplot(x='TotalPay Actual', y='TotalPay Predicted', data=prediction_results2)
_ = plt.title('Model 2 - Actual vs Predicted Salaries')
_ = plt.xlabel('Actual Salary')
_ = plt.ylabel('Predicted Salary')
plt.show()
# Out:
# Model 2 R-squared:  0.8123601101462732
# Model 2 RMSE:  881072.0121053094
# Model 2 MAE:  710496.8217966057

# %% [markdown]
# # What is the single biggest impact on salary size?
#
# 1.   Stadardized data
# 2.   Program Revenue is the most important to the model (which makes sense)

# %%
# standardizing dataframe
from scipy import stats
import statsmodels.formula.api as smf
df_z = df_model2.select_dtypes(include=[np.number]).dropna().apply(stats.zscore)

# %%
features2 = ['Capacity','SOS','SRS','Bowl W','School Win %','Program Revenue']
# Build training and testing sets
X_train2, X_test2, y_train2, y_test2 = train_test_split(df_z[features2], df_z[target_name], 
                                                   test_size=0.33, random_state=19)

# %%
# Builds the model
model2 = sm.OLS(y_train2, X_train2)

# Fits the model
results2 = model2.fit()

# Model results
print(results2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               TotalPay   R-squared (uncentered):                   0.856
# Model:                            OLS   Adj. R-squared (uncentered):              0.843
# Method:                 Least Squares   F-statistic:                              66.12
# Date:                Sun, 25 Jul 2021   Prob (F-statistic):                    3.23e-26
# Time:                        12:34:23   Log-Likelihood:                         -31.449
# No. Observations:                  73   AIC:                                      74.90
# Df Residuals:                      67   BIC:                                      88.64
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Capacity            0.1630      0.108      1.508      0.136      -0.053       0.379
# SOS                 0.2128      0.075      2.839      0.006       0.063       0.362
# SRS                 0.1268      0.075      1.683      0.097      -0.024       0.277
# Bowl W              0.1440      0.063      2.273      0.026       0.018       0.270
# School Win %        0.0986      0.064      1.537      0.129      -0.029       0.227
# Program Revenue     0.3533      0.101      3.501      0.001       0.152       0.555
# ==============================================================================
# Omnibus:                        1.237   Durbin-Watson:                   1.575
# Prob(Omnibus):                  0.539   Jarque-Bera (JB):                0.631
# Skew:                          -0.018   Prob(JB):                        0.729
# Kurtosis:                       3.454   Cond. No.                         6.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import matplotlib
import matplotlib.pyplot as pyplot
# get importance
importance = results2.params
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.16302
# Feature: 1, Score: 0.21282
# Feature: 2, Score: 0.12680
# Feature: 3, Score: 0.14397
# Feature: 4, Score: 0.09863
# Feature: 5, Score: 0.35329

# %%
df_feature_importance = pd.DataFrame(importance,columns=['feature importance'])
df_feature_importance=df_feature_importance.sort_values('feature importance', ascending=False)
df_feature_importance
# Out:
#                  feature importance
# Program Revenue            0.353287
# SOS                        0.212817
# Capacity                   0.163021
# Bowl W                     0.143969
# SRS                        0.126795
# School Win %               0.098629

# %%
df_feature_importance.plot(kind='bar')

# %% [markdown]
# # Random Forest Exploration

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=1000, oob_score=True, random_state=19)
rf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=True,
#                       random_state=19, verbose=0, warm_start=False)

# %%
from sklearn.metrics import r2_score
from scipy.stats import spearmanr
from sklearn.metrics import accuracy_score
predicted_train = rf.predict(X_train)
predicted_test = rf.predict(X_test)
test_score = r2_score(y_test, predicted_test)
spearman = spearmanr(y_test, predicted_test)
print(f'Out-of-bag R-2 score estimate: {rf.oob_score_:>5.3}')
print(f'Test data R-2 score: {test_score:>5.3}')
print(f'Test data Spearman correlation: {spearman[0]:.3}')
# Out:
# Out-of-bag R-2 score estimate: 0.796
# Test data R-2 score: 0.732
# Test data Spearman correlation: 0.874
